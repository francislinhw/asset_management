# %% [markdown]
# # Step1: 十隻股票資料

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader.data as web
df1 = web.DataReader("^GSPC", "yahoo", start="2014-6-1", end="2019-5-31")       #美股S&P 500
df2 = web.DataReader("^STOXX50E", "yahoo", start="2014-6-1", end="2019-5-31")       #歐洲STOXX 50
df3 = web.DataReader("^N225", "yahoo", start="2014-6-1", end="2019-5-31")         #日經225
df4 = web.DataReader("000001.SS", "yahoo", start="2014-6-1", end="2019-5-31")            #上證000001.SS
df5= web.DataReader("^HSI", "yahoo", start="2014-6-1", end="2019-5-31")           #恆生hang seng index
df6 = web.DataReader("^TWII", "yahoo", start="2014-6-1", end="2019-5-31")         #台股加權
df7 = web.DataReader("^TNX", "yahoo", start="2014-6-1", end="2019-5-31")         #美國10年債券
df8 = web.DataReader("LQD", "yahoo", start="2014-6-1", end="2019-5-31")         #投資等級債券
df9 = web.DataReader("VWEHX", "yahoo", start="2014-6-1", end="2019-5-31")         #高收益債 VWEHX
df10 = web.DataReader("EEM", "yahoo", start="2014-6-1", end="2019-5-31")            #新興市場債

#使用Adj Close來繪製圖表

A = df1["Adj Close"]        
B = df2["Adj Close"]   
C = df3["Adj Close"]
D = df4["Adj Close"]
E = df5["Adj Close"]        
F = df6["Adj Close"]
G = df7["Adj Close"]
H = df8["Adj Close"]        
I = df9["Adj Close"]
J = df10["Adj Close"]

A.plot()
B.plot()
C.plot()
D.plot()
E.plot()
F.plot()
G.plot()
H.plot()
I.plot()
J.plot()

# %% [markdown]
# # Step2: 計算報酬率(profit)/風險(risk)

# %%
import tkinter as tk

# %%
from datetime import *
while True:
    pad=input('請輸入想回測到西元幾年-幾月-幾日(系統只能回朔到2014-6-1):')
    pdd=datetime.strptime(pad,'%Y-%m-%d')
    dpp=datetime.strptime('2014-6-1','%Y-%m-%d')
    td=datetime.today()
    diff1=td-pdd
    diff2=td-dpp
    pddd=int(str(diff1.days))
    dppp=int(str(diff2.days))
    if pddd<dppp:
        print('總共要回測',pddd,'天')         #請使用者輸入pddd
        break
    else:
        print('請輸入2014-6-1以後的日期')
        continue
# Out:
# 請輸入想回測到西元幾年-幾月-幾日(系統只能回朔到2014-6-1):2019-1-1
# 總共要回測 177 天

# %%
profitA =A.diff()/A     #diff函數是用來計算「差距」
profitA[-pddd:].plot()    #近pddd天的投資報酬率
profitB = B.diff()/B
profitB[-pddd:].plot() 
profitC = C.diff()/C
profitC[-pddd:].plot() 
profitD = D.diff()/D
profitD[-pddd:].plot() 
profitE = E.diff()/E
profitE[-pddd:].plot() 
profitF = F.diff()/F
profitF[-pddd:].plot() 
profitG = G.diff()/G
profitG[-pddd:].plot() 
profitH = H.diff()/H
profitH[-pddd:].plot() 
profitI = I.diff()/I
profitI[-pddd:].plot() 
profitJ = J.diff()/J
profitJ[-pddd:].plot() 

#profit = A.pct_change()       pct_change可以直接算出「百分比」，不用A.diff()/A   可以改成profit= A.pct_change()
#profit[-100:].plot()                 #近pddd天的投資報酬率

# %% [markdown]
# # 印出「日報酬率」/以及「平均報酬率」（一個數字）

# %%
profitA =A.diff()/A   
a=profitA[-pddd:]
print(a)
print(a.mean())

profitB = B.diff()/B
b=profitB[-pddd:] 
print(b)
print(b.mean())

profitC = C.diff()/C
c=profitC[-pddd:]
print(c)
print(c.mean())

profitD = D.diff()/D
d=profitD[-pddd:]
print(d)
print(d.mean())

profitE = E.diff()/E
e=profitE[-pddd:]
print(e)
print(e.mean())

profitF = F.diff()/F
f=profitF[-pddd:]
print(f)
print(f.mean())

profitG = G.diff()/G
g=profitG[-pddd:]
print(g)
print(g.mean())

profitH = H.diff()/H
h=profitH[-pddd:]
print(h)
print(h.mean())

profitI = I.diff()/I
i=profitI[-pddd:]
print(i)
print(i.mean())

profitJ = J.diff()/J
j=profitJ[-pddd:]
print(j)
print(j.mean())
# Out:
# Date
# 2018-09-17   -0.005601
# 2018-09-18    0.005340
# 2018-09-19    0.001252
# 2018-09-20    0.007780
# 2018-09-21   -0.000369
# 2018-09-24   -0.003528
# 2018-09-25   -0.001307
# 2018-09-26   -0.003300
# 2018-09-27    0.002756
# 2018-09-28   -0.000007
# 2018-10-01    0.003628
# 2018-10-02   -0.000397
# 2018-10-03    0.000711
# 2018-10-04   -0.008237
# 2018-10-05   -0.005559
# 2018-10-08   -0.000395
# 2018-10-09   -0.001420
# 2018-10-10   -0.033981
# 2018-10-11   -0.021005
# 2018-10-12    0.014007
# 2018-10-15   -0.005940
# 2018-10-16    0.021043
# 2018-10-17   -0.000253
# 2018-10-18   -0.014602
# 2018-10-19   -0.000361
# 2018-10-22   -0.004318
# 2018-10-23   -0.005542
# 2018-10-24   -0.031847
# 2018-10-25    0.018284
# 2018-10-26   -0.017633
#                 ...
# 2019-04-18    0.001577
# 2019-04-22    0.001011
# 2019-04-23    0.008764
# 2019-04-24   -0.002197
# 2019-04-25   -0.000369
# 2019-04-26    0.004663
# 2019-04-29    0.001070
# 2019-04-30    0.000951
# 2019-05-01   -0.007559
# 2019-05-02   -0.002129
# 2019-05-03    0.009546
# 2019-05-06   -0.004491
# 2019-05-07   -0.016789
# 2019-05-08   -0.001608
# 2019-05-09   -0.003031
# 2019-05-10    0.003707
# 2019-05-13   -0.024727
# 2019-05-14    0.007952
# 2019-05-15    0.005805
# 2019-05-16    0.008817
# 2019-05-17   -0.005872
# 2019-05-20   -0.006795
# 2019-05-21    0.008424
# 2019-05-22   -0.002832
# 2019-05-23   -0.012058
# 2019-05-24    0.001352
# 2019-05-28   -0.008446
# 2019-05-29   -0.006960
# 2019-05-30    0.002094
# 2019-05-31   -0.013372
# Name: Adj Close, Length: 177, dtype: float64
# -0.000365560446581169
# Date
# 2018-07-26    0.011629
# 2018-07-27    0.005081
# 2018-07-30   -0.004234
# 2018-07-31    0.003738
# 2018-08-02   -0.016223
# 2018-08-03    0.003788
# 2018-08-06    0.000258
# 2018-08-07    0.006013
# 2018-08-08   -0.003083
# 2018-08-09    0.000154
# 2018-08-10   -0.019806
# 2018-10-02   -0.012739
# 2018-10-03   -0.008325
# 2018-10-04   -0.025616
# 2018-10-05   -0.003673
# 2018-10-08    0.001467
# 2018-10-09   -0.003681
# 2018-10-10   -0.030602
# 2018-10-11   -0.010220
# 2018-10-12    0.028543
# 2018-10-15   -0.010788
# 2018-10-16    0.024474
# 2018-10-17   -0.012389
# 2018-10-18   -0.026972
# 2018-10-19    0.009327
# 2018-10-22    0.010723
# 2018-10-23   -0.011094
# 2018-10-24   -0.033351
# 2018-10-25    0.018916
# 2018-10-26   -0.011637
#                 ...
# 2019-04-18   -0.000673
# 2019-04-22   -0.006551
# 2019-04-23    0.002254
# 2019-04-24   -0.013708
# 2019-04-25   -0.001373
# 2019-04-26    0.003874
# 2019-04-29    0.002047
# 2019-04-30   -0.000911
# 2019-05-01   -0.007569
# 2019-05-02    0.002288
# 2019-05-03    0.011759
# 2019-05-06   -0.021011
# 2019-05-07   -0.020019
# 2019-05-08   -0.001415
# 2019-05-09   -0.016056
# 2019-05-10    0.005955
# 2019-05-13   -0.034500
# 2019-05-14    0.013852
# 2019-05-15    0.001940
# 2019-05-16   -0.004874
# 2019-05-17   -0.018367
# 2019-05-20   -0.004237
# 2019-05-21    0.012552
# 2019-05-22   -0.004947
# 2019-05-23   -0.013029
# 2019-05-24    0.001001
# 2019-05-28    0.003492
# 2019-05-29    0.006444
# 2019-05-30    0.005423
# 2019-05-31    0.003439
# Name: Adj Close, Length: 177, dtype: float64
# -0.00016545866421271163

# %% [markdown]
# # 風險（標準差）（報酬的波動）

# %%
# 風險（標準差）（報酬的波動）
riskA = a.std()
riskB = b.std()
riskC = c.std()
riskD = d.std()
riskE = e.std()
riskF = f.std()
riskG = g.std()
riskH = h.std()
riskI = i.std()
riskJ = j.std()

# %% [markdown]
# # Step3: 相關係數

# %%
adjclose = {'美股S&P 500':A,'歐洲STOXX 50':B,'日經225':C,'上證000001.SS':D,'恆生hang seng index':E,'台股加權':F,'美國10年債券':G,'投資等級債券':H,'高收益債 VWEHX':I,'新興市場債':J}
adjclose = pd.DataFrame(adjclose)
corr = adjclose.corr()
corr.head(10)
# Out:
#                    美股S&P 500  歐洲STOXX 50     日經225  上證000001.SS  \
# 美股S&P 500           1.000000    0.434159  0.864026    -0.032962
# 歐洲STOXX 50          0.434159    1.000000  0.675683     0.542534
# 日經225               0.864026    0.675683  1.000000     0.335557
# 上證000001.SS        -0.032962    0.542534  0.335557     1.000000
# 恆生hang seng index   0.801774    0.670997  0.799869     0.210489
# 台股加權                0.872249    0.602281  0.754111     0.035642
# 美國10年債券             0.686802    0.386710  0.675846    -0.222013
# 投資等級債券              0.822849    0.234289  0.581034    -0.009324
# 高收益債 VWEHX          0.954188    0.396567  0.771406    -0.033584
# 新興市場債               0.772741    0.582399  0.662695    -0.027949
#
#                    恆生hang seng index      台股加權   美國10年債券    投資等級債券  \
# 美股S&P 500                   0.801774  0.872249  0.686802  0.822849
# 歐洲STOXX 50                  0.670997  0.602281  0.386710  0.234289
# 日經225                       0.799869  0.754111  0.675846  0.581034
# 上證000001.SS                 0.210489  0.035642 -0.222013 -0.009324
# 恆生hang seng index           1.000000  0.909832  0.634121  0.589659
# 台股加權                        0.909832  1.000000  0.613909  0.722299
# 美國10年債券                     0.634121  0.613909  1.000000  0.209145
# 投資等級債券                      0.589659  0.722299  0.209145  1.000000
# 高收益債 VWEHX                  0.742875  0.849267  0.561282  0.913529
# 新興市場債                       0.946186  0.930306  0.645463  0.597635
#
#                    高收益債 VWEHX     新興市場債
# 美股S&P 500            0.954188  0.772741
# 歐洲STOXX 50           0.396567  0.582399
# 日經225                0.771406  0.662695
# 上證000001.SS         -0.033584 -0.027949
# 恆生hang seng index    0.742875  0.946186
# 台股加權                 0.849267  0.930306
# 美國10年債券              0.561282  0.645463
# 投資等級債券               0.913529  0.597635
# 高收益債 VWEHX           1.000000  0.737489
# 新興市場債                0.737489  1.000000

# %%
import seaborn as sns
sns.heatmap(corr, square=True ,vmax=1.0, linecolor='white', annot=True)

# %% [markdown]
# # Step4: 夏普指數（供投資人參考，以利未來資產配置）

# %%
#下列我們額外乘了一個「252 ** 0.5」
#夏普率= [(每日報酬率平均值- 無風險利率) / (每日報酬的標準差)]x (252平方根)
#作用是算出「年化的夏普指數」(annual sharpe ratio)
#其中的252是一年大約的交易天數
#之所以乘這個常數，是因為乘上這個數字才有辦法跟別人比較！
sharpeA = (a / riskA) * (252 ** 0.5)
sharpeB = (b / riskB) * (252 ** 0.5)
sharpeC = (c / riskC) * (252 ** 0.5)
sharpeD = (d / riskD) * (252 ** 0.5)
sharpeE = (e / riskE) * (252 ** 0.5)
sharpeF = (f / riskF) * (252 ** 0.5)
sharpeG = (g / riskG) * (252 ** 0.5)
sharpeH = (h / riskH) * (252 ** 0.5)
sharpeI = (i/ riskI) * (252 ** 0.5)
sharpeJ = (j / riskJ) * (252 ** 0.5)

# %% [markdown]
# # 畫出夏普指數時序圖

# %%
sharpeA.plot()
sharpeB.plot()
sharpeC.plot()
sharpeD.plot()
sharpeE.plot()
sharpeF.plot()
sharpeG.plot()
sharpeH.plot()
sharpeI.plot()
sharpeJ.plot()

# %% [markdown]
# # 用移動窗格的方式計算移動平均，獲得較為平滑的移動平均線

# %%
x = 5 #以「週」為單位
shmuA = sharpeA.rolling(x).mean()
shmuB = sharpeB.rolling(x).mean()
shmuC = sharpeC.rolling(x).mean()
shmuD = sharpeD.rolling(x).mean()
shmuE = sharpeE.rolling(x).mean()
shmuF = sharpeF.rolling(x).mean()
shmuG = sharpeG.rolling(x).mean()
shmuH = sharpeH.rolling(x).mean()
shmuI = sharpeI.rolling(x).mean()
shmuJ = sharpeJ.rolling(x).mean()

# %% [markdown]
# # 畫出夏普指數圖(藍線)，以及移動平均圖(橘線)，10隻股票分開畫

# %%
sharpeA.plot() #美股S&P 500
shmuA.plot()

# %%
sharpeB.plot() #歐洲STOXX 50
shmuB.plot()

# %%
sharpeC.plot() #日經225
shmuC.plot()

# %%
sharpeD.plot() #上證000001.SS
shmuD.plot()

# %%
sharpeE.plot() #恆生hang seng index
shmuE.plot()

# %%
sharpeF.plot() #台股加權
shmuF.plot()

# %%
sharpeG.plot() #美國10年債券
shmuG.plot()

# %%
sharpeH.plot() #投資等級債券
shmuH.plot()

# %%
sharpeI.plot() #高收益債 VWEHX
shmuI.plot()

# %%
sharpeJ.plot() #新興市場債
shmuJ.plot()

# %%
#雖然夏普公式沒有完全正確，不過依然可以經由這個公式知道「越高此比率越好」
shA = (a.mean() / riskA) * (252 ** 0.5)
shB = (b.mean()) / riskB * (252 ** 0.5)
shC = (c.mean()) / riskC * (252 ** 0.5)
shD = (d.mean()) / riskD * (252 ** 0.5)
shE = (e.mean()) / riskE * (252 ** 0.5)
shF = (f.mean()) / riskF * (252 ** 0.5)
shG = (g.mean()) / riskG * (252 ** 0.5)
shH = (h.mean()) / riskH * (252 ** 0.5)
shI = (i.mean()) / riskI * (252 ** 0.5)
shJ = (j.mean()) / riskJ * (252 ** 0.5)

# %%
ind = ['美股S&P 500','歐洲STOXX 50','日經225','上證000001.SS','恆生hang seng index','台股加權','美國10年債券','投資等級債券','高收益債 VWEHX','新興市場債']
stocks = [str(shA), str(shB), str(shC), str(shD), str(shE), str(shF), str(shG), str(shH), str(shI), str(shJ)]
shdf = pd.DataFrame(stocks, index = ind, columns = ['平均夏普指數'])
shdf
# Out:
#                                  平均夏普指數
# 美股S&P 500            -0.528006538173724
# 歐洲STOXX 50          -0.3091406253831976
# 日經225               -0.8555847012931601
# 上證000001.SS         0.22903019595299137
# 恆生hang seng index  -0.11327525173071445
# 台股加權                -0.5183900922162147
# 美國10年債券             -2.3710785513009576
# 投資等級債券                2.730022484626943
# 高收益債 VWEHX           1.1248884895157785
# 新興市場債              -0.20843468295466808

# %% [markdown]
# # Step5: 做主視窗讓使用者做資產配置

# %%
import tkinter
from tkinter import messagebox


#作主視窗讓使用者自行調配投資組合
win=tkinter.Tk()   #建立新的主視窗，一個程式只能有一個主視窗
win.title('投資組合')   #主視窗的標題
win.geometry('500x500')   #主視窗的大小，寬度x高度
def addition():
    done=False
    while(not done):
        target = num1.get()+ num2.get()+num3.get()+ num4.get()+ num5.get() +num6.get()+num7.get() +num8.get()+ num9.get()+ num10.get()
        if target != 100:
                done = True
                messagebox.showinfo('警告!', '加總不是100%，請重新輸入')
        break
    resultr.set((num1.get()*riskA + num2.get()*riskB+num3.get()*riskC+ num4.get()*riskD+ num5.get()*riskE +num6.get()*riskF +num7.get()*riskG +num8.get()*riskH+ num9.get()*riskI+ num10.get()*riskJ)/100)
    resultp.set((num1.get()*a.mean() + num2.get()*b.mean()+num3.get()*c.mean()+ num4.get()*d.mean()+ num5.get()*e.mean() +num6.get()*f.mean() +num7.get()*g.mean() +num8.get()*h.mean()+ num9.get()*i.mean()+ num10.get()*j.mean())/100)
    #return(resultr,resultp)
#用get()來取得num1~num10的值  #用set()來設定result的值
num1=tkinter.IntVar()
num2=tkinter.IntVar()
num3=tkinter.IntVar()
num4=tkinter.IntVar()
num5=tkinter.IntVar()
num6=tkinter.IntVar()
num7=tkinter.IntVar()
num8=tkinter.IntVar()
num9=tkinter.IntVar()
num10=tkinter.IntVar()
resultr=tkinter.DoubleVar()
resultp=tkinter.DoubleVar()
item1=tkinter.Entry(win, width=10, textvariable=num1).grid(row=0,column=0)
label1=tkinter.Label(win, width=15, text='美股S&P 500').grid(row=0,column=2)
item2=tkinter.Entry(win, width=10, textvariable=num2).grid(row=1,column=0)
label2=tkinter.Label(win, width=15, text='歐洲STOXX 50').grid(row=1,column=2)
item3=tkinter.Entry(win, width=10, textvariable=num3).grid(row=2,column=0)
label3=tkinter.Label(win, width=15, text='日經225').grid(row=2,column=2)
item4=tkinter.Entry(win, width=10, textvariable=num4).grid(row=3,column=0)
label4=tkinter.Label(win, width=15, text='上證000001.SS').grid(row=3,column=2)
item5=tkinter.Entry(win, width=10, textvariable=num5).grid(row=4,column=0)
label5=tkinter.Label(win, width=15, text='恆生hang seng index').grid(row=4,column=2)
item6=tkinter.Entry(win, width=10, textvariable=num6).grid(row=5,column=0)
label6=tkinter.Label(win, width=15, text='台股加權').grid(row=5,column=2)
item7=tkinter.Entry(win, width=10, textvariable=num7).grid(row=6,column=0)
label7=tkinter.Label(win, width=15, text='美國10年債券').grid(row=6,column=2)
item8=tkinter.Entry(win, width=10, textvariable=num8).grid(row=7,column=0)
label8=tkinter.Label(win, width=15, text='投資等級債券').grid(row=7,column=2)
item9=tkinter.Entry(win, width=10, textvariable=num9).grid(row=8,column=0)
label9=tkinter.Label(win, width=15, text='收益債 VWEHX ').grid(row=8,column=2)
item10=tkinter.Entry(win, width=10, textvariable=num10).grid(row=9,column=0)
label10=tkinter.Label(win, width=15, text='新興市場債').grid(row=9,column=2)
btn=tkinter.Button(win, width=5, text='確認', command=addition).grid(row=10,column=0)
label11=tkinter.Label(win, width=25, textvariable=resultr).grid(row=11,column=2)
label112=tkinter.Label(win, width=15, text='風險').grid(row=11,column=0)
label12=tkinter.Label(win, width=25, textvariable=resultp).grid(row=12,column=2)
label122=tkinter.Label(win, width=15, text='報酬率').grid(row=12,column=0)
labela=tkinter.Label(win, width=5, text='%的').grid(row=0,column=1)
labelb=tkinter.Label(win, width=5, text='%的').grid(row=1,column=1)
labelc=tkinter.Label(win, width=5, text='%的').grid(row=2,column=1)
labeld=tkinter.Label(win, width=5, text='%的').grid(row=3,column=1)
labele=tkinter.Label(win, width=5, text='%的').grid(row=4,column=1)
labelf=tkinter.Label(win, width=5, text='%的').grid(row=5,column=1)
labelg=tkinter.Label(win, width=5, text='%的').grid(row=6,column=1)
labelh=tkinter.Label(win, width=5, text='%的').grid(row=7,column=1)
labeli=tkinter.Label(win, width=5, text='%的').grid(row=8,column=1)
labelj=tkinter.Label(win, width=5, text='%的').grid(row=9,column=1)
win.mainloop()
